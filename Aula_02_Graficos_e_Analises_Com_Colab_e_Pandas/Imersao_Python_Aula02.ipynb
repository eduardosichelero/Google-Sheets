# %% [markdown]
# <a href="https://colab.research.google.com/github/rosacarla/graficos-e-analises-com-Google-Colab-e-Python-Pandas/blob/main/Imersao_Python_Aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importa biblioteca Pandas do Python

import pandas as pd

# %%
# Criada variavel para receber a leitura da aba Principal da planilha acoes-pura.xlsx
df_principal = pd.read_excel("acoes-pura.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
# ...

# %%
# Criada variavel para receber a leitura da aba Gotal_deacoes da planilha acoes-pura.xlsx
df_total_acoes = pd.read_excel("/content/acoes-pura.xlsx", sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
# Criada variavel para receber a leitura da aba Ticker da planilha acoes-pura.xlsx
df_ticker = pd.read_excel("/content/acoes-pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
# Criada variavel para receber a leitura da aba ChatGPT da planilha acoes-pura.xlsx
df_chatgpt = pd.read_excel("/content/acoes-pura.xlsx", sheet_name="ChatGPT")
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração            50
# 2          Petrobras           Petróleo            68
# 3             Suzano   Papel e Celulose            95
# 4       CPFL Energia   Energia Elétrica            90
# ..               ...                ...           ...
# 73  Carrefour Brasil             Varejo            45
# 74       Casas Bahia             Varejo            70
# 75          Localiza  Aluguel de Carros            45
# 76               CVC            Turismo            50
# 77               GOL   Transporte Aéreo            20
#
# [78 rows x 3 columns]
